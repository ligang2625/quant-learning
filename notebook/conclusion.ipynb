# %% [markdown]
# 固定使用 20/60 双均线策略后，5 只股票中有若干只在年化收益上跑赢买入持有，但所有股票都出现了最大回撤改善。策略的主要作用不是稳定提高收益，而是在趋势转弱时降低暴露，从而控制下行风险。不过夏普比率并没有普遍改善，说明该策略可能牺牲了部分收益稳定性，也可能在震荡阶段受到反复交易影响。

# %% [markdown]
# 20/60在左侧行情中表现很好，往往能够快速止跌，但是在右侧行情和震荡行情中表现很差，往往会出现高买低卖的操作
